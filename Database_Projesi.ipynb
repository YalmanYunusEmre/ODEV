# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/apple_quality.csv")

# %%
# bunlar deneme tabiki bunlar sayılmaz :D
df.head()
df.tail()
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN

# %%
df.head(10)
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# 5   5.0 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
# 6   6.0  1.331606  1.635956   0.875974    -1.677798   3.106344 -1.847417
# 7   7.0 -1.995462 -0.428958   1.530644    -0.742972   0.158834  0.974438
# 8   8.0 -3.867632 -3.734514   0.986429    -1.207655   2.292873  4.080921
# 9   9.0 -0.727983 -0.442820  -4.092223     0.597513   0.393714  1.620857
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good
# ...

# %%
df.shape
# Out:
# (4001, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4001 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
schema_df = pd.read_csv("/content/apple_quality.csv")

# %%
schema_df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
schema_df.shape
# Out:
# (4001, 9)

# %%
df["Size"].value_counts()
# Out:
# -3.970049    1
# -3.844134    1
# -4.411655    1
# -1.480046    1
#  0.749942    1
#             ..
# -2.385353    1
#  0.612499    1
#  0.862280    1
#  2.181630    1
#  0.278540    1
# Name: Size, Length: 4000, dtype: int64

# %%
df["Weight"].value_counts()
# Out:
# -2.512336    1
# -2.729138    1
#  2.702494    1
# -0.326744    1
# -2.590200    1
#             ..
# -2.367245    1
# -3.353272    1
# -1.644647    1
# -3.755985    1
# -1.715505    1
# Name: Weight, Length: 4000, dtype: int64

# %%
df["Sweetness"]
# Out:
# 0       5.346330
# 1       3.664059
# 2      -1.738429
# 3       1.324874
# 4      -0.384658
#           ...
# 3996   -0.204020
# 3997   -2.440461
# 3998    2.366397
# 3999    0.121217
# 4000         NaN
# Name: Sweetness, Length: 4001, dtype: float64

# %%
df.drop("Ripeness", axis=1, inplace=True)

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874
# ...      ...       ...       ...        ...          ...        ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677
# 4000     NaN       NaN       NaN        NaN          NaN        NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874
# ...      ...       ...       ...        ...          ...        ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677
# 4000     NaN       NaN       NaN        NaN          NaN        NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# ...

# %%
df.drop([2, 3], axis=0, inplace=True)

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874
# 5        5.0 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071
# 6        6.0  1.331606  1.635956   0.875974    -1.677798   3.106344
# ...      ...       ...       ...        ...          ...        ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677
# 4000     NaN       NaN       NaN        NaN          NaN        NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# ...

# %%
df.iloc[1:3]
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness       Acidity  \
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  -0.722809367
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874   0.501984036
#
#   Quality
# 1    good
# 4    good

# %%
df.loc[0, "Sweetness"]
# Out:
# 5.346329613

# %%
new_col_names = ["Numara", "Büyüklük" ,"Ağırlık", "Tatlılık", "Kütürlük", "Sululuk", "Asitlilik", "Kalite"]
df.columns = new_col_names

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874
# 5        5.0 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071
# 6        6.0  1.331606  1.635956   0.875974    -1.677798   3.106344
# ...      ...       ...       ...        ...          ...        ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677
# 4000     NaN       NaN       NaN        NaN          NaN        NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# ...

# %%
filt = (df["Kütürlük"] > 1.0 ) & (df["Kalite"] == "bad")
df.loc[filt]
# Out:
#       Numara  Büyüklük   Ağırlık  Tatlılık  Kütürlük   Sululuk     Asitlilik  \
# 12      12.0 -0.170812 -1.867271 -1.771845  2.413155 -3.094555  -2.076113997
# 18      18.0 -0.302364  1.724396 -2.442337  3.465108  0.449792   2.493781985
# 23      23.0  0.135714 -0.753757 -2.196146  1.039276  0.580538   2.086618541
# 24      24.0  0.522961 -1.428085 -0.743519  1.786716 -4.207544  -1.430429857
# 27      27.0  1.999831  0.669990 -2.099616  2.645819 -0.989496  -2.397691796
# ...      ...       ...       ...       ...       ...       ...           ...
# 3976  3976.0 -0.524415  0.897921 -1.377694  1.579954  0.994690   2.422747057
# 3977  3977.0 -0.845026 -0.668021 -1.760759  1.867993 -1.408950  -0.772829229
# 3984  3984.0 -0.832533  0.463473 -0.843983  1.489058 -2.205796   0.725999977
# 3990  3990.0 -1.396794 -0.599596 -1.931104  1.815668  1.670732  -0.987967575
# 3993  3993.0  1.520142 -0.352623 -3.206467  1.341719  0.675568  -0.945080106
#
#      Kalite
# 12      bad
# 18      bad
# ...

# %%
df.loc[(df.Yumuşaklık == 0) & (df.Kalite == "good")]
# Out:
# Empty DataFrame
# Columns: [Numara, Büyüklük, Ağırlık, Tatlılık, Kütürlük, Sululuk, Asitlilik, Kalite, Yumuşaklık]
# Index: []

# %%
df[(df.Asitlilik > 1) & (df.Kalite == "bad")]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-0088d32e0573> in <cell line: 1>()
# ----> 1 df[(df.Asitlilik > 1) & (df.Kalite == "bad")]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      56     @unpack_zerodim_and_defer("__gt__")
#      57     def __gt__(self, other):
# ---> 58         return self._cmp_method(other, operator.gt)
#      59
#      60     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6241
#    6242         with np.errstate(all="ignore"):
# ...

# %%
df[(df.Tatlılık > 1) & (df.Kalite == "good")]
# Out:
#       Numara  Büyüklük   Ağırlık  Tatlılık  Kütürlük   Sululuk     Asitlilik  \
# 0        0.0 -3.970049 -2.512336  5.346330 -1.012009  1.844900  -0.491590483
# 1        1.0 -1.195217 -2.839257  3.664059  1.588232  0.853286  -0.722809367
# 7        7.0 -1.995462 -0.428958  1.530644 -0.742972  0.158834  -1.470125066
# 13      13.0 -1.345531 -1.623701  2.044144  1.754813  0.997567   1.724026084
# 15      15.0 -2.659887 -2.795684  4.230404  0.697550  2.180911  -1.083620788
# ...      ...       ...       ...       ...       ...       ...           ...
# 3965  3965.0 -2.810655 -1.550996  2.699335  1.032748  1.788077  -3.167304356
# 3970  3970.0 -1.103217 -1.944869  2.173498  0.192773  0.256211  -0.684437591
# 3980  3980.0 -2.492583 -2.065917  1.081180  1.267673 -1.600722   0.627116568
# 3983  3983.0 -3.652936 -1.117509  3.271792 -1.266320  2.360319  -2.022186257
# 3998  3998.0 -4.008004 -1.779337  2.366397 -0.200329  2.161435  -2.229719806
#
#      Kalite  Yumuşaklık
# ...

# %%
df["Kütürlük"].head(18)
# Out:
# 0    -1.012009
# 1     1.588232
# 4    -0.553006
# 5    -0.555775
# 6    -1.677798
# 7    -0.742972
# 8    -1.207655
# 9     0.597513
# 10   -0.625546
# 11    0.942400
# 12    2.413155
# 13    1.754813
# 14    0.894581
# 15    0.697550
# 16    0.909759
# 17    2.935319
# 18    3.465108
# 19    4.326723
# Name: Kütürlük, dtype: float64

# %%
df[["Kütürlük", "Tatlılık"]].head(11)
# Out:
#     Kütürlük  Tatlılık
# 0  -1.012009  5.346330
# 1   1.588232  3.664059
# 4  -0.553006 -0.384658
# 5  -0.555775 -1.913511
# 6  -1.677798  0.875974
# 7  -0.742972  1.530644
# 8  -1.207655  0.986429
# 9   0.597513 -4.092223
# 10 -0.625546 -1.418507
# 11  0.942400 -1.635041
# 12  2.413155 -1.771845

# %%
df["Yumuşaklık"] = df.Kütürlük / 5.5

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874
# 5        5.0 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071
# 6        6.0  1.331606  1.635956   0.875974    -1.677798   3.106344
# ...      ...       ...       ...        ...          ...        ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677
# 4000     NaN       NaN       NaN        NaN          NaN        NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# ...

# %%
numbers = [1, 2, 3, 4, 5]

first_number = numbers[0]
second_number = numbers[1]

numbers[2] = 10

numbers.append(6)
numbers.insert(1, 7)

removed_number = numbers.pop(3)

for number in numbers:
    print(number)

is_five_in_list = 5 in numbers

index_of_six = numbers.index(6)

list_length = len(numbers)

numbers.sort()

numbers.reverse()

subset_of_numbers = numbers[1:4]

copied_numbers = numbers.copy()

numbers.clear()

print("Modified List:", numbers)
print("Original List:", copied_numbers)
# Out:
# 1
# 7
# 2
# 4
# 5
# 6
# Modified List: []
# Original List: [7, 6, 5, 4, 2, 1]

# %%
import matplotlib.pyplot as plt

labels = ['Kütürlük', 'Yumuşaklık', 'Sululuk', 'Asitlik', 'Tatlılık', 'Ağırlık', 'Kalite', 'Numara', 'Büyüklük']
sizes = [15, 30, 20, 5, 10, 3, 1, 1, 15]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.axis('equal')

plt.show()

# %%
plt.style.use("fivethirtyeight")

slices = [59219, 55466, 47544, 36443, 35917, ]
labels = ['Sululuk', 'Kütürlük','Tatlılık', 'Yumuşaklık', 'Asitlik']
explode = [0,0,0,0.1,0]

plt.pie(
    slices,labels=labels,
    wedgeprops={"edgecolor":"black"},
    explode=explode,
    shadow=True,
    startangle=90,
    autopct='%1.1f%%')

plt.title("Apple Quality Chart")
plt.tight_layout()
plt.show()
